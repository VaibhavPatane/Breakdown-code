# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavPatane/Breakdown-code/blob/main/practicalLa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 4+2j
b=3-5j
print("Adition of two complex",a+b)
# Out:
# Adition of two complex (7-3j)

# %%
import matplotlib.pyplot as plt
x = 2 + 4j
z = 1j
plt.scatter(x.real,x.imag,color='red')
c = x * z
plt.scatter(c.real, c.imag)
plt.show()

# %%
''' Conjugate Of A Complex Number'''
a = 4 + 2j
a.conjugate()
# Out:
# (4-2j)
